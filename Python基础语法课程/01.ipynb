# %%
print('hi')
# Out:
# 运行具有“Python 3.12.10”的单元格需要ipykernel包。
#
# 将“ipykernel”安装到 Python 环境中。
#
# 命令:“c:/Users/Lenovo/AppData/Local/Programs/Python/Python312/python.exe -m pip install ipykernel -U --user --force-reinstall”

# %%
“c:/Users/Lenovo/AppData/Local/Programs/Python/Python312/python.exe -m pip install ipykernel -U --user --force-reinstall”
